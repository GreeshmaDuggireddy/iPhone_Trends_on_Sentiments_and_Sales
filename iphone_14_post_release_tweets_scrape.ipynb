# %%
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git

import os
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-tv8ach03
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-tv8ach03
# ...

# %%
tweet_count = 15000
text_query = "iphone 14"
since_date = "2022-09-17"
until_date = "2022-12-11"

os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> iphone_14_post_release_tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
tweets_df1 = pd.read_json('iphone_14_post_release_tweets.json', lines=True)
tweets_df1
# Out:
#                                 _type  \
# 0      snscrape.modules.twitter.Tweet
# 1      snscrape.modules.twitter.Tweet
# 2      snscrape.modules.twitter.Tweet
# 3      snscrape.modules.twitter.Tweet
# 4      snscrape.modules.twitter.Tweet
# ...                               ...
# 14995  snscrape.modules.twitter.Tweet
# 14996  snscrape.modules.twitter.Tweet
# 14997  snscrape.modules.twitter.Tweet
# 14998  snscrape.modules.twitter.Tweet
# 14999  snscrape.modules.twitter.Tweet
#
#                                                      url  \
# 0      https://twitter.com/leonardopaez/status/160172...
# 1      https://twitter.com/EightKomo/status/160172837...
# 2      https://twitter.com/AppleStore_KT/status/16017...
# 3      https://twitter.com/perry_monk/status/16017281...
# 4      https://twitter.com/akiatoji/status/1601728129...
# ...                                                  ...
# 14995  https://twitter.com/slltano/status/16009481152...
# ...

# %%
tweets_df1.to_csv('iphone_14_post_release.csv', sep=',', index=False)
